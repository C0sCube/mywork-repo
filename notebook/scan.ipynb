# %%
dir_path = r"C:\Users\Kaustubh.keny\OneDrive - Cogencis Information Services Ltd\Documents\mywork-repo"
fund_path = r"C:\Users\Kaustubh.keny\OneDrive - Cogencis Information Services Ltd\Documents\Dec 24"
import sys, os
sys.path.append(os.path.abspath(dir_path))

import fitz, ocrmypdf
from app.helper import Helper

# %%
file_path = dir_path + r'\data\input\output.pdf'

# %%
import ocrmypdf

input_pdf = file_path
# output_pdf = dir_path + '\data\input\output.pdf'

# ocrmypdf.ocr(input_pdf, output_pdf, language="eng", deskew=True)

# %%
data = Helper.get_pdf_text(file_path)

# %%
for page ,content in data.items():
    print(f"________Page Number: {page +1}_________")
    for text in content:
        print(text)
# Out:
# ________Page Number: 1_________
# STANPACKS stifit
# R (INDIA) LTD.
# WE SHARE OUR JOY
# AN ISO 9001 : 2015 COMPANY CIN : L36991TN1991PLC021888
# SSE-43 /2024-25 11.02.2025
# To
# Bombay Stock Exchange Ltd.,
# PhirozeJeejeebhoy Towers,
# 25th Floor, Dalal Street,
# Mumbai-400 001
# Dear Sirs,
# Ref: SCRIP CODE NO.530931
# Sub: Integrated Filing (Financial) for the quarter and period ended December 31,
# 2024
# Pursuant to SEBI Circular No. SEBI/HO/CFD/CFD-PoD-2/CIR/P/2024/185 dated
# December 31, 2024, read with BSE Circular No. 20250102-4 dated January 2, 2025, we
# are submitting herewith the Integrated Filing (Financial) for the quarter and period
# ended December 31, 2024.
# Please find the same in order and acknowledge the receipt.
# Thanking you,
# Yours faithfully,
# For STANPACKS (INDIA) LIMITED
# Digitally signed by
# RAJESHWAR RAJESHWARI MOORTHY
# Date: 2025.02.11
# | MOORTH 10:19:51 +05'30'
# Rajeshwari Moorthy
# Company Secretary and Compliance Officer
# ...
