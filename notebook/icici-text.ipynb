# %%
import pdfplumber
import fitz
import warnings , math, collections , os, re, pprint, json
import pickle
import numpy as np
import pandas as pd



warnings.filterwarnings("ignore", category=UserWarning) 


path = r"C:\Users\Kaustubh.keny\OneDrive - Cogencis Information Services Ltd\Documents\mywork-repo"
#path = r"C:\Users\rando\OneDrive\Documents\mywork-repo"

# %%
icici_path = path + r"\files\icici-factsheet.pdf"
dry_path  = path + r"\output\DryRun.pdf"
indice_path = path + r"\output\pkl\indices_var.pkl"

# %%
def get_financial_indices(path:str):
    final_indices = set()
    with open(path , 'rb') as file:
        indices = pickle.load(file)  
        for k,v in indices.items():
            temp = [k] + v
            for t in temp:
                final_indices.add(t)
    
    return final_indices


""" Highlights important financial indices in the pdf, does other pre
analysis of data.
Args: list of indices, string of pdf path
Returns: dict of pages highlighted, string of output pdf, dict of pages contaiting FUND NAMES
"""
def check_indice_highlight(path:str, indices_variations:list, fund_pattern:str, fund_size:int):
    doc = fitz.open(path)
    page_count = doc.page_count #No of pages
    
    pages = [i for i in range(page_count)]
    important_pages = dict.fromkeys(pages, 0)
    fund_titles = dict.fromkeys(pages, "")


    for page_num, page in enumerate(doc):
        
        text_instances = page.get_text('dict')["blocks"]
        
        #sort for all data in pdf document 
        sorted_text_instances = sorted(text_instances, key=lambda x: (x['bbox'][1], x['bbox'][0]))
        
        # rect = fitz.Rect((35,120,250,765))
        # page.add_highlight_annot(rect)

        for pgn,block in enumerate(sorted_text_instances):     
            if "lines" not in block:
                continue
            
            for line in block["lines"]: 
                for span in line["spans"]:
                    if span['flags'] in [20,25, 16,0 ,4]:  # learn flag logic , rn set for all flags value
                        span_text = span['text'].strip().lower()
                        
                        
                        #FUND PAGE CHECK
                        conditions = [
                            pgn in range(0,6),
                            re.match(fund_pattern, span_text, re.IGNORECASE),
                            span['size'] > fund_size
                        ]
                        if all(conditions):
        
                            fund_titles[page_num] = span_text
                            #print(span_text,page_num)
                        
                        #CHECK IMP FINANCE INDICES  
                        for term in indices_variations:  
                            pattern = r'\b' + re.escape(term.lower()) + r'\b'
                            if re.search(pattern, span_text):

                                #count highlights
                                important_pages[page_num] +=1
                                #mark content
                                rect = fitz.Rect(span['bbox']) 
                                page.add_highlight_annot(rect)
                                break  #optional , one highlight

    
    output_path = None
    if any(important_pages.values()):
        output_path = path.replace('.pdf', '_highlighted.pdf')
        doc.save(output_path)

    doc.close()
    return important_pages, output_path, fund_titles


""" Get the clipped data in the bbox provided and store in nested dict
Args: input path, dryrun path, important pages, bbox coords
Returns: dict { 'page' : int 'block': dict}"""
def get_clipped_data(input:str, output:str, pageSelect:list, bbox:list[set], fund_names:dict):
    
    document = fitz.open(input)
    finalData = []
    
    for pgn in pageSelect:
        #get the page
        page = document[pgn]
        fundName = fund_names[pgn]
    
        blocks = page.get_text('dict', clip = bbox[0])['blocks'] #get all blocks
        
        filtered_blocks = [block for block in blocks if block['type']==0 and 'lines' in block]
        sorted_blocks = sorted(filtered_blocks, key= lambda x: (x['bbox'][1], x['bbox'][0]))
        
        finalData.append({
            "page": pgn,
            "fundname": fundName,
            "block": sorted_blocks,
        })
            
    return finalData

def extract_span_data(data:list, name:str): #all
    final_data = dict()
    for pgn,page in enumerate(data):
        pgn_content = []
        for blocks in page['block']:
            for line in blocks['lines']:
                spans = line.get('spans',[])
                for span in spans:
                    pgn_content.append(span[name])
                
        final_data[f"Page: {pgn + 1}"] = pgn_content
    
    return final_data

# %%
file_path = icici_path
final_indices = get_financial_indices(indice_path)
fund_pattern = r"^(samco|tata|canara|ICICI|BHARAT)" #.*(fund|ETF|\)|FOF|Plan|-)$
fund_size = 14

highlight_pages, saved_path, fund_pages =  check_indice_highlight(file_path, final_indices, fund_pattern, fund_size)

# %%
"""_summary_ fund is located only on certain pages, based on no. of 
highlights we know which pages are imp. automate this content later
"""
pagedf = pd.DataFrame({'page_num': [i for i in range(172)],'title': fund_pages.values(),'highlight_count': highlight_pages.values()})
pagedf.to_excel(path+r'\output\example.xlsx')
fund_dict = pagedf.to_dict()
#print(pagedf)

# %%
pages = list()
fund_names = list()
for num,fund,count in zip(fund_dict['page_num'].values(), fund_dict['title'].values(),fund_dict['highlight_count'].values()):
    
    if count >2 and fund !="":
        pages.append(num)
        fund_names.append(fund)
        
#pages

# %%
document = fitz.open(icici_path)
finalData = []

for pgn, fund in zip(pages, fund_names):
    #get the page
    page = document[pgn]


    blocks = page.get_text('dict') #get all blocks
    
    filtered_blocks = [block for block in blocks['blocks'] if block['type']==0 and 'lines' in block]
    sorted_blocks = sorted(blocks['blocks'], key= lambda x: (x['bbox'][1],x['bbox'][0]))
    
    finalData.append({
        "page": pgn,
        "fund": fund,
        "block": sorted_blocks,
        "only_block": blocks
    })

# %%
finalData[0]['only_block']
# Out:
# [{'number': 0,
#   'type': 0,
#   'bbox': (558.4761962890625,
#    760.5255737304688,
#    566.3641357421875,
#    768.5255737304688),
#   'lines': [{'spans': [{'size': 8.0,
#       'flags': 20,
#       'font': 'ZurichBT-BoldCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': '16',
#       'origin': (558.4761962890625, 772.2178955078125),
#       'bbox': (558.4761962890625,
#        760.5255737304688,
#        566.3641357421875,
#        768.5255737304688)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (558.4761962890625,
#      760.5255737304688,
#      566.3641357421875,
#      768.5255737304688)}]},
#  {'number': 1,
#   'type': 0,
#   'bbox': (59.05839920043945,
#    84.94588470458984,
#    90.9573974609375,
#    91.94588470458984),
#   'lines': [{'spans': [{'size': 7.0,
#       'flags': 20,
#       'font': 'Arial-BoldMT',
#       'color': -65794,
#       'ascender': 0.7279999852180481,
#       'descender': -0.20999999344348907,
#       'text': 'Style Box',
#       'origin': (59.05839920043945, 90.37872314453125),
#       'bbox': (59.05839920043945,
#        84.94588470458984,
#        90.9573974609375,
#        91.94588470458984)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (59.05839920043945,
#      84.94588470458984,
#      90.9573974609375,
#      91.94588470458984)}]},
#  {'number': 2,
#   'type': 0,
#   'bbox': (133.46432495117188,
#    182.5098114013672,
#    562.8777465820312,
#    199.8762664794922),
#   'lines': [{'spans': [{'size': 5.5,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Notes:',
#       'origin': (133.46670532226562, 190.54827880859375),
#       'bbox': (133.46670532226562,
#        182.5098114013672,
#        147.20021057128906,
#        188.0098114013672)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (133.46670532226562,
#      182.5098114013672,
#      147.20021057128906,
#      188.0098114013672)},
#    {'spans': [{'size': 5.5,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': '1.\xa0Different plans shall have different expense structure. The performance details provided herein are of ICICI Prudential Bluechip Fund.',
#       'origin': (133.46670532226562, 196.48150634765625),
#       'bbox': (133.46670532226562,
#        188.4430389404297,
#        404.18365478515625,
#        193.9430389404297)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (133.46670532226562,
#      188.4430389404297,
#      404.18365478515625,
#      193.9430389404297)},
#    {'spans': [{'size': 5.5,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': '2.\xa0The scheme is currently managed by Anish Tawakley, Rajat Chandak and Vaibhav Dusad. Mr. Anish Tawakley has been managing this fund since Sep 2018. Total Schemes managed by the Fund Manager is 5 (5 ',
#       'origin': (133.46432495117188, 202.41473388671875),
#       'bbox': (133.46432495117188,
#        194.3762664794922,
#        562.8777465820312,
#        199.8762664794922)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (133.46432495117188,
#      194.3762664794922,
#      562.8777465820312,
#      199.8762664794922)}]},
#  {'number': 3,
#   'type': 0,
#   'bbox': (133.4449462890625,
#    200.3097381591797,
#    562.8697509765625,
#    247.3435516357422),
#   'lines': [{'spans': [{'size': 5.5,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'are jointly managed). ',
#       'origin': (139.70852661132812, 208.34820556640625),
#       'bbox': (139.70852661132812,
#        200.3097381591797,
#        183.78611755371094,
#        205.8097381591797)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (139.70852661132812,
#      200.3097381591797,
#      183.78611755371094,
#      205.8097381591797)},
#    {'spans': [{'size': 5.5,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': ' ',
#       'origin': (133.4584197998047, 214.28167724609375),
#       'bbox': (133.4584197998047,
#        206.2432098388672,
#        134.77842712402344,
#        211.7432098388672)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (133.4584197998047,
#      206.2432098388672,
#      134.77842712402344,
#      211.7432098388672)},
#    {'spans': [{'size': 5.5,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Mr. Rajat Chandak has been managing this fund since Jul 2017. Total Schemes managed by the Fund Manager is 5 (4 are jointly managed).',
#       'origin': (139.70852661132812, 214.28167724609375),
#       'bbox': (139.70852661132812,
#        206.2432098388672,
#        417.00640869140625,
#        211.7432098388672)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (139.70852661132812,
#      206.2432098388672,
#      417.00640869140625,
#      211.7432098388672)},
#    {'spans': [{'size': 5.5,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': ' ',
#       'origin': (133.45574951171875, 220.21514892578125),
#       'bbox': (133.45574951171875,
#        212.1766815185547,
#        134.7757568359375,
#        217.6766815185547)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (133.45574951171875,
#      212.1766815185547,
#      134.7757568359375,
#      217.6766815185547)},
#    {'spans': [{'size': 5.5,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Mr. Vaibhav Dusad has been managing this fund since Jan 2021. Total Schemes managed by the Fund Manager is 3 (2 are jointly managed).  Refer annexure from page no. 134 for performance of other schemes ',
#       'origin': (139.7058563232422, 220.21514892578125),
#       'bbox': (139.7058563232422,
#        212.1766815185547,
#        562.8697509765625,
#        217.6766815185547)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (139.7058563232422,
#      212.1766815185547,
#      562.8697509765625,
#      217.6766815185547)},
#    {'spans': [{'size': 5.5,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'currently managed by Anish Tawakley, Rajat Chandak and Vaibhav Dusad.',
#       'origin': (139.70004272460938, 226.14837646484375),
#       'bbox': (139.70004272460938,
#        218.1099090576172,
#        288.43896484375,
#        223.6099090576172)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (139.70004272460938,
#      218.1099090576172,
#      288.43896484375,
#      223.6099090576172)},
#    {'spans': [{'size': 5.5,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': '3.  Date of inception:23-May-08.',
#       'origin': (133.44834899902344, 232.08160400390625),
#       'bbox': (133.44834899902344,
#        224.0431365966797,
#        199.57330322265625,
#        229.5431365966797)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (133.44834899902344,
#      224.0431365966797,
#      199.57330322265625,
#      229.5431365966797)},
#    {'spans': [{'size': 5.5,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': '4.  Past performance may or may not be sustained in future and the same may not necessarily provide the basis for comparison with other investment.',
#       'origin': (133.4481658935547, 238.01507568359375),
#       'bbox': (133.4481658935547,
#        229.9766082763672,
#        434.5790100097656,
#        235.4766082763672)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (133.4481658935547,
#      229.9766082763672,
#      434.5790100097656,
#      235.4766082763672)},
#    {'spans': [{'size': 5.5,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': '5.  Load is not considered for computation of returns.',
#       'origin': (133.44583129882812, 243.94854736328125),
#       'bbox': (133.44583129882812,
#        235.9100799560547,
#        239.68443298339844,
#        241.4100799560547)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (133.44583129882812,
#      235.9100799560547,
#      239.68443298339844,
#      241.4100799560547)},
#    {'spans': [{'size': 5.5,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': '6.  In case, the start/end date of the concerned period is a nonbusiness date (NBD), the NAV of the previous date is considered for computation of returns. The NAV per unit shown in the table is as on the start date of ',
#       'origin': (133.4449462890625, 249.88201904296875),
#       'bbox': (133.4449462890625,
#        241.8435516357422,
#        562.86083984375,
#        247.3435516357422)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (133.4449462890625,
#      241.8435516357422,
#      562.86083984375,
#      247.3435516357422)}]},
#  {'number': 4,
#   'type': 0,
#   'bbox': (133.43551635742188,
#    247.7767791748047,
#    520.1853637695312,
#    259.21002197265625),
#   'lines': [{'spans': [{'size': 5.5,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'the said period',
#       'origin': (139.68621826171875, 255.81524658203125),
#       'bbox': (139.68621826171875,
#        247.7767791748047,
#        169.35191345214844,
#        253.2767791748047)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (139.68621826171875,
#      247.7767791748047,
#      169.35191345214844,
#      253.2767791748047)},
#    {'spans': [{'size': 5.5,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': '7.  The performance of the scheme is benchmarked to the Total Return variant of the Index. The benchmark of the scheme has been revised from Nifty 50 TRI to Nifty 100 TRI w.e.f. May 28, 2018.',
#       'origin': (133.43551635742188, 261.74847412109375),
#       'bbox': (133.43551635742188,
#        253.7100067138672,
#        520.1853637695312,
#        259.21002197265625)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (133.43551635742188,
#      253.7100067138672,
#      520.1853637695312,
#      259.21002197265625)}]},
#  {'number': 5,
#   'type': 0,
#   'bbox': (212.96490478515625,
#    73.77369689941406,
#    477.2635803222656,
#    81.77369689941406),
#   'lines': [{'spans': [{'size': 8.0,
#       'flags': 20,
#       'font': 'ZurichBT-BoldCondensed',
#       'color': -5360585,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Returns of ICICI Prudential Bluechip Fund - Growth Option as on October 31, 2021 ',
#       'origin': (212.96490478515625, 85.46600341796875),
#       'bbox': (212.96490478515625,
#        73.77369689941406,
#        477.2635803222656,
#        81.77369689941406)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (212.96490478515625,
#      73.77369689941406,
#      477.2635803222656,
#      81.77369689941406)}]},
#  {'number': 6,
#   'type': 0,
#   'bbox': (136.89979553222656,
#    87.97241973876953,
#    551.9501342773438,
#    94.97241973876953),
#   'lines': [{'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -65794,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': '1 Year',
#       'origin': (320.2091979980469, 98.20318603515625),
#       'bbox': (320.2091979980469,
#        87.97241973876953,
#        336.45733642578125,
#        94.97241973876953)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (320.2091979980469,
#      87.97241973876953,
#      336.45733642578125,
#      94.97241973876953)},
#    {'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -65794,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': '3 Years',
#       'origin': (386.6820068359375, 98.20318603515625),
#       'bbox': (386.6820068359375,
#        87.97241973876953,
#        405.92584228515625,
#        94.97241973876953)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (386.6820068359375,
#      87.97241973876953,
#      405.92584228515625,
#      94.97241973876953)},
#    {'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -65794,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': '5 Years',
#       'origin': (454.2533874511719, 98.20318603515625),
#       'bbox': (454.2533874511719,
#        87.97241973876953,
#        473.4972229003906,
#        94.97241973876953)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (454.2533874511719,
#      87.97241973876953,
#      473.4972229003906,
#      94.97241973876953)},
#    {'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -65794,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Since inception',
#       'origin': (511.3150939941406, 98.20318603515625),
#       'bbox': (511.3150939941406,
#        87.97241973876953,
#        551.9501342773438,
#        94.97241973876953)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (511.3150939941406,
#      87.97241973876953,
#      551.9501342773438,
#      94.97241973876953)},
#    {'spans': [{'size': 7.0,
#       'flags': 20,
#       'font': 'ZurichBT-BoldCondensed',
#       'color': -65794,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Particulars',
#       'origin': (136.89979553222656, 98.20318603515625),
#       'bbox': (136.89979553222656,
#        87.97241973876953,
#        167.47085571289062,
#        94.97241973876953)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (136.89979553222656,
#      87.97241973876953,
#      167.47085571289062,
#      94.97241973876953)}]},
#  {'number': 7,
#   'type': 0,
#   'bbox': (319.4515075683594,
#    167.4737548828125,
#    402.6585693359375,
#    174.47711181640625),
#   'lines': [{'spans': [{'size': 7.0,
#       'flags': 20,
#       'font': 'ZurichBT-BoldCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': '41.90',
#       'origin': (319.4515075683594, 177.70452880859375),
#       'bbox': (319.4515075683594,
#        167.4737548828125,
#        334.9844665527344,
#        174.4737548828125)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (319.4515075683594,
#      167.4737548828125,
#      334.9844665527344,
#      174.4737548828125)},
#    {'spans': [{'size': 7.0,
#       'flags': 20,
#       'font': 'ZurichBT-BoldCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': '39.28',
#       'origin': (387.1256103515625, 177.7078857421875),
#       'bbox': (387.1256103515625,
#        167.47711181640625,
#        402.6585693359375,
#        174.47711181640625)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (387.1256103515625,
#      167.47711181640625,
#      402.6585693359375,
#      174.47711181640625)}]},
#  {'number': 8,
#   'type': 0,
#   'bbox': (137.3477020263672,
#    133.584716796875,
#    157.32872009277344,
#    140.084716796875),
#   'lines': [{'spans': [{'size': 6.5,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Scheme',
#       'origin': (137.3477020263672, 143.084716796875),
#       'bbox': (137.3477020263672,
#        133.584716796875,
#        157.32872009277344,
#        140.084716796875)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (137.3477020263672,
#      133.584716796875,
#      157.32872009277344,
#      140.084716796875)}]},
#  {'number': 9,
#   'type': 0,
#   'bbox': (137.3477020263672,
#    144.1318359375,
#    202.815673828125,
#    150.6318359375),
#   'lines': [{'spans': [{'size': 6.5,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Nifty 100 TRI (Benchmark)',
#       'origin': (137.3477020263672, 153.6318359375),
#       'bbox': (137.3477020263672,
#        144.1318359375,
#        202.815673828125,
#        150.6318359375)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (137.3477020263672,
#      144.1318359375,
#      202.815673828125,
#      150.6318359375)}]},
#  {'number': 10,
#   'type': 0,
#   'bbox': (137.3477020263672,
#    154.678955078125,
#    225.97518920898438,
#    161.178955078125),
#   'lines': [{'spans': [{'size': 6.5,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Nifty 50 TRI (Additional Benchmark)',
#       'origin': (137.3477020263672, 164.178955078125),
#       'bbox': (137.3477020263672,
#        154.678955078125,
#        225.97518920898438,
#        161.178955078125)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (137.3477020263672,
#      154.678955078125,
#      225.97518920898438,
#      161.178955078125)}]},
#  {'number': 11,
#   'type': 0,
#   'bbox': (137.3477020263672,
#    167.60528564453125,
#    269.10479736328125,
#    174.10528564453125),
#   'lines': [{'spans': [{'size': 6.5,
#       'flags': 20,
#       'font': 'ZurichBT-BoldCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'NAV (Rs.) Per Unit (as on October 29,2021 : 65.95)',
#       'origin': (137.3477020263672, 177.10528564453125),
#       'bbox': (137.3477020263672,
#        167.60528564453125,
#        269.10479736328125,
#        174.10528564453125)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (137.3477020263672,
#      167.60528564453125,
#      269.10479736328125,
#      174.10528564453125)}]},
#  {'number': 12,
#   'type': 0,
#   'bbox': (300.7351989746094,
#    99.86743927001953,
#    318.0672302246094,
#    106.86743927001953),
#   'lines': [{'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -65794,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'CAGR ',
#       'origin': (300.7351989746094, 110.09820556640625),
#       'bbox': (300.7351989746094,
#        99.86743927001953,
#        318.0672302246094,
#        106.86743927001953)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (300.7351989746094,
#      99.86743927001953,
#      318.0672302246094,
#      106.86743927001953)}]},
#  {'number': 13,
#   'type': 0,
#   'bbox': (304.289794921875,
#    107.41895294189453,
#    312.8298034667969,
#    114.41895294189453),
#   'lines': [{'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -65794,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': '(%)',
#       'origin': (304.289794921875, 117.64971923828125),
#       'bbox': (304.289794921875,
#        107.41895294189453,
#        312.8298034667969,
#        114.41895294189453)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (304.289794921875,
#      107.41895294189453,
#      312.8298034667969,
#      114.41895294189453)}]},
#  {'number': 14,
#   'type': 0,
#   'bbox': (324.24249267578125,
#    99.85352325439453,
#    358.3661804199219,
#    129.508056640625),
#   'lines': [{'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -65794,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Current ',
#       'origin': (331.3476867675781, 110.08428955078125),
#       'bbox': (331.3476867675781,
#        99.85352325439453,
#        352.459716796875,
#        106.85352325439453)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (331.3476867675781,
#      99.85352325439453,
#      352.459716796875,
#      106.85352325439453)},
#    {'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -65794,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Value of',
#       'origin': (330.5462951660156, 117.63580322265625),
#       'bbox': (330.5462951660156,
#        107.40503692626953,
#        351.5834045410156,
#        114.40503692626953)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (330.5462951660156,
#      107.40503692626953,
#      351.5834045410156,
#      114.40503692626953)},
#    {'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -65794,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': ' Investment ',
#       'origin': (325.4382019042969, 125.18731689453125),
#       'bbox': (325.4382019042969,
#        114.95655059814453,
#        358.3661804199219,
#        121.95655059814453)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (325.4382019042969,
#      114.95655059814453,
#      358.3661804199219,
#      121.95655059814453)},
#    {'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -65794,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'of Rs. 10000',
#       'origin': (324.24249267578125, 132.73883056640625),
#       'bbox': (324.24249267578125,
#        122.50806427001953,
#        357.88446044921875,
#        129.508056640625)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (324.24249267578125,
#      122.50806427001953,
#      357.88446044921875,
#      129.508056640625)}]},
#  {'number': 15,
#   'type': 0,
#   'bbox': (368.3664855957031,
#    99.86743927001953,
#    385.6985168457031,
#    106.86743927001953),
#   'lines': [{'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -65794,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'CAGR ',
#       'origin': (368.3664855957031, 110.09820556640625),
#       'bbox': (368.3664855957031,
#        99.86743927001953,
#        385.6985168457031,
#        106.86743927001953)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (368.3664855957031,
#      99.86743927001953,
#      385.6985168457031,
#      106.86743927001953)}]},
#  {'number': 16,
#   'type': 0,
#   'bbox': (371.9208984375,
#    107.41895294189453,
#    380.4609069824219,
#    114.41895294189453),
#   'lines': [{'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -65794,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': '(%)',
#       'origin': (371.9208984375, 117.64971923828125),
#       'bbox': (371.9208984375,
#        107.41895294189453,
#        380.4609069824219,
#        114.41895294189453)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (371.9208984375,
#      107.41895294189453,
#      380.4609069824219,
#      114.41895294189453)}]},
#  {'number': 17,
#   'type': 0,
#   'bbox': (391.87432861328125,
#    99.85352325439453,
#    425.9977111816406,
#    129.508056640625),
#   'lines': [{'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -65794,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Current ',
#       'origin': (398.9789123535156, 110.08428955078125),
#       'bbox': (398.9789123535156,
#        99.85352325439453,
#        420.0909423828125,
#        106.85352325439453)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (398.9789123535156,
#      99.85352325439453,
#      420.0909423828125,
#      106.85352325439453)},
#    {'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -65794,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Value of',
#       'origin': (398.1778259277344, 117.63580322265625),
#       'bbox': (398.1778259277344,
#        107.40503692626953,
#        419.2146301269531,
#        114.40503692626953)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (398.1778259277344,
#      107.40503692626953,
#      419.2146301269531,
#      114.40503692626953)},
#    {'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -65794,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': ' Investment ',
#       'origin': (393.0697326660156, 125.18731689453125),
#       'bbox': (393.0697326660156,
#        114.95655059814453,
#        425.9977111816406,
#        121.95655059814453)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (393.0697326660156,
#      114.95655059814453,
#      425.9977111816406,
#      121.95655059814453)},
#    {'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -65794,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'of Rs. 10000',
#       'origin': (391.87432861328125, 132.73883056640625),
#       'bbox': (391.87432861328125,
#        122.50806427001953,
#        425.51629638671875,
#        129.508056640625)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (391.87432861328125,
#      122.50806427001953,
#      425.51629638671875,
#      129.508056640625)}]},
#  {'number': 18,
#   'type': 0,
#   'bbox': (435.9977111816406,
#    99.86743927001953,
#    453.3297424316406,
#    106.86743927001953),
#   'lines': [{'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -65794,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'CAGR ',
#       'origin': (435.9977111816406, 110.09820556640625),
#       'bbox': (435.9977111816406,
#        99.86743927001953,
#        453.3297424316406,
#        106.86743927001953)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (435.9977111816406,
#      99.86743927001953,
#      453.3297424316406,
#      106.86743927001953)}]},
#  {'number': 19,
#   'type': 0,
#   'bbox': (439.55230712890625,
#    107.41895294189453,
#    448.0923156738281,
#    114.41895294189453),
#   'lines': [{'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -65794,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': '(%)',
#       'origin': (439.55230712890625, 117.64971923828125),
#       'bbox': (439.55230712890625,
#        107.41895294189453,
#        448.0923156738281,
#        114.41895294189453)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (439.55230712890625,
#      107.41895294189453,
#      448.0923156738281,
#      114.41895294189453)}]},
#  {'number': 20,
#   'type': 0,
#   'bbox': (459.50531005859375,
#    99.85352325439453,
#    493.6289978027344,
#    129.508056640625),
#   'lines': [{'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -65794,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Current ',
#       'origin': (466.6101989746094, 110.08428955078125),
#       'bbox': (466.6101989746094,
#        99.85352325439453,
#        487.72222900390625,
#        106.85352325439453)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (466.6101989746094,
#      99.85352325439453,
#      487.72222900390625,
#      106.85352325439453)},
#    {'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -65794,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Value of',
#       'origin': (465.8088073730469, 117.63580322265625),
#       'bbox': (465.8088073730469,
#        107.40503692626953,
#        486.8459167480469,
#        114.40503692626953)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (465.8088073730469,
#      107.40503692626953,
#      486.8459167480469,
#      114.40503692626953)},
#    {'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -65794,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': ' Investment ',
#       'origin': (460.7010192871094, 125.18731689453125),
#       'bbox': (460.7010192871094,
#        114.95655059814453,
#        493.6289978027344,
#        121.95655059814453)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (460.7010192871094,
#      114.95655059814453,
#      493.6289978027344,
#      121.95655059814453)},
#    {'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -65794,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'of Rs. 10000',
#       'origin': (459.50531005859375, 132.73883056640625),
#       'bbox': (459.50531005859375,
#        122.50806427001953,
#        493.14727783203125,
#        129.508056640625)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (459.50531005859375,
#      122.50806427001953,
#      493.14727783203125,
#      129.508056640625)}]},
#  {'number': 21,
#   'type': 0,
#   'bbox': (454.57769775390625,
#    167.4808349609375,
#    470.11065673828125,
#    174.4808349609375),
#   'lines': [{'spans': [{'size': 7.0,
#       'flags': 20,
#       'font': 'ZurichBT-BoldCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': '32.28',
#       'origin': (454.57769775390625, 177.71160888671875),
#       'bbox': (454.57769775390625,
#        167.4808349609375,
#        470.11065673828125,
#        174.4808349609375)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (454.57769775390625,
#      167.4808349609375,
#      470.11065673828125,
#      174.4808349609375)}]},
#  {'number': 22,
#   'type': 0,
#   'bbox': (503.62890625, 99.86743927001953, 520.9609375, 106.86743927001953),
#   'lines': [{'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -65794,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'CAGR ',
#       'origin': (503.62890625, 110.09820556640625),
#       'bbox': (503.62890625,
#        99.86743927001953,
#        520.9609375,
#        106.86743927001953)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (503.62890625,
#      99.86743927001953,
#      520.9609375,
#      106.86743927001953)}]},
#  {'number': 23,
#   'type': 0,
#   'bbox': (507.1835021972656,
#    107.41895294189453,
#    515.7235107421875,
#    114.41895294189453),
#   'lines': [{'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -65794,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': '(%)',
#       'origin': (507.1835021972656, 117.64971923828125),
#       'bbox': (507.1835021972656,
#        107.41895294189453,
#        515.7235107421875,
#        114.41895294189453)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (507.1835021972656,
#      107.41895294189453,
#      515.7235107421875,
#      114.41895294189453)}]},
#  {'number': 24,
#   'type': 0,
#   'bbox': (527.1365356445312,
#    99.85352325439453,
#    561.2598876953125,
#    129.508056640625),
#   'lines': [{'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -65794,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Current ',
#       'origin': (534.2413940429688, 110.08428955078125),
#       'bbox': (534.2413940429688,
#        99.85352325439453,
#        555.3534545898438,
#        106.85352325439453)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (534.2413940429688,
#      99.85352325439453,
#      555.3534545898438,
#      106.85352325439453)},
#    {'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -65794,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Value of',
#       'origin': (533.4403076171875, 117.63580322265625),
#       'bbox': (533.4403076171875,
#        107.40503692626953,
#        554.4771118164062,
#        114.40503692626953)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (533.4403076171875,
#      107.40503692626953,
#      554.4771118164062,
#      114.40503692626953)},
#    {'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -65794,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': ' Investment ',
#       'origin': (528.3319091796875, 125.18731689453125),
#       'bbox': (528.3319091796875,
#        114.95655059814453,
#        561.2598876953125,
#        121.95655059814453)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (528.3319091796875,
#      114.95655059814453,
#      561.2598876953125,
#      121.95655059814453)},
#    {'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -65794,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'of Rs. 10000',
#       'origin': (527.1365356445312, 132.73883056640625),
#       'bbox': (527.1365356445312,
#        122.50806427001953,
#        560.7786254882812,
#        129.508056640625)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (527.1365356445312,
#      122.50806427001953,
#      560.7786254882812,
#      129.508056640625)}]},
#  {'number': 25,
#   'type': 0,
#   'bbox': (522.260498046875,
#    167.3854522705078,
#    538.0731201171875,
#    174.4481658935547),
#   'lines': [{'spans': [{'size': 7.062718868255615,
#       'flags': 20,
#       'font': 'ZurichBT-BoldCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': '10.00',
#       'origin': (522.260498046875, 177.7078857421875),
#       'bbox': (522.260498046875,
#        167.3854522705078,
#        538.0731201171875,
#        174.4481658935547)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (522.260498046875,
#      167.3854522705078,
#      538.0731201171875,
#      174.4481658935547)}]},
#  {'number': 26,
#   'type': 0,
#   'bbox': (150.63900756835938,
#    413.50482177734375,
#    256.0400390625,
#    420.50482177734375),
#   'lines': [{'spans': [{'size': 7.0,
#       'flags': 20,
#       'font': 'ZurichBT-Bold',
#       'color': -65794,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Portfolio as on October 31, 2021',
#       'origin': (150.63900756835938, 423.735595703125),
#       'bbox': (150.63900756835938,
#        413.50482177734375,
#        256.0400390625,
#        420.50482177734375)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (150.63900756835938,
#      413.50482177734375,
#      256.0400390625,
#      420.50482177734375)}]},
#  {'number': 27,
#   'type': 0,
#   'bbox': (271.6026916503906,
#    266.43572998046875,
#    312.6318054199219,
#    273.43572998046875),
#   'lines': [{'spans': [{'size': 7.0,
#       'flags': 20,
#       'font': 'ZurichBT-Bold',
#       'color': -65794,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Fund Details',
#       'origin': (271.6026916503906, 276.66650390625),
#       'bbox': (271.6026916503906,
#        266.43572998046875,
#        312.6318054199219,
#        273.43572998046875)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (271.6026916503906,
#      266.43572998046875,
#      312.6318054199219,
#      273.43572998046875)}]},
#  {'number': 28,
#   'type': 0,
#   'bbox': (219.7480010986328,
#    310.055419921875,
#    359.46954345703125,
#    316.76593017578125),
#   'lines': [{'spans': [{'size': 6.710514068603516,
#       'flags': 20,
#       'font': 'ZurichBT-BoldCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Monthly AAUM as on 31-Oct-21 :  ',
#       'origin': (219.7480010986328, 319.86309814453125),
#       'bbox': (219.7480010986328,
#        310.055419921875,
#        308.6836853027344,
#        316.76593017578125)},
#      {'size': 6.710514068603516,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Rs. 31,369.46 crores',
#       'origin': (308.6809387207031, 319.86309814453125),
#       'bbox': (308.6809387207031,
#        310.055419921875,
#        359.46954345703125,
#        316.76593017578125)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (219.7480010986328,
#      310.055419921875,
#      359.46954345703125,
#      316.76593017578125)}]},
#  {'number': 29,
#   'type': 0,
#   'bbox': (219.8123016357422,
#    320.2173156738281,
#    368.0029602050781,
#    329.03570556640625),
#   'lines': [{'spans': [{'size': 6.710514068603516,
#       'flags': 20,
#       'font': 'ZurichBT-BoldCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Closing AUM as on 31-Oct-21 : ',
#       'origin': (219.8123016357422, 330.0249938964844),
#       'bbox': (219.8123016357422,
#        320.2173156738281,
#        300.9522705078125,
#        326.9278259277344)},
#      {'size': 6.710514068603516,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Rs. 31,081.90 crores',
#       'origin': (300.94989013671875, 330.0249938964844),
#       'bbox': (300.94989013671875,
#        320.2173156738281,
#        351.7384948730469,
#        326.9278259277344)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (219.8123016357422,
#      320.2173156738281,
#      351.7384948730469,
#      326.9278259277344)},
#    {'spans': [{'size': 7.390192985534668,
#       'flags': 4,
#       'font': 'MalgunGothic',
#       'color': -13159371,
#       'ascender': 0.800000011920929,
#       'descender': -0.20000000298023224,
#       'text': '`',
#       'origin': (365.98541259765625, 327.5631103515625),
#       'bbox': (365.98541259765625,
#        321.6726989746094,
#        368.0029602050781,
#        329.03570556640625)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (365.98541259765625,
#      321.6726989746094,
#      368.0029602050781,
#      329.03570556640625)}]},
#  {'number': 30,
#   'type': 0,
#   'bbox': (35.03450012207031,
#    286.7579345703125,
#    173.06399536132812,
#    308.8603515625),
#   'lines': [{'spans': [{'size': 7.0,
#       'flags': 20,
#       'font': 'ZurichBT-BoldCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Fund Managers** :',
#       'origin': (35.03960037231445, 296.98870849609375),
#       'bbox': (35.03960037231445,
#        286.7579345703125,
#        87.65641021728516,
#        293.7579345703125)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (35.03960037231445,
#      286.7579345703125,
#      87.65641021728516,
#      293.7579345703125)},
#    {'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Anish Tawakley (Managing this fund since Sep, 2018 ',
#       'origin': (35.038204193115234, 304.5399169921875),
#       'bbox': (35.038204193115234,
#        294.30914306640625,
#        173.06399536132812,
#        301.30914306640625)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (35.038204193115234,
#      294.30914306640625,
#      173.06399536132812,
#      301.30914306640625)},
#    {'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': '& Overall 26 years of experience)',
#       'origin': (35.03450012207031, 312.09112548828125),
#       'bbox': (35.03450012207031,
#        301.8603515625,
#        120.3023910522461,
#        308.8603515625)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (35.03450012207031,
#      301.8603515625,
#      120.3023910522461,
#      308.8603515625)}]},
#  {'number': 31,
#   'type': 0,
#   'bbox': (35.027984619140625,
#    316.9630432128906,
#    167.40037536621094,
#    331.5145568847656),
#   'lines': [{'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Rajat Chandak (Managing this fund since Jul, 2017 ',
#       'origin': (35.03148651123047, 327.1938171386719),
#       'bbox': (35.03148651123047,
#        316.9630432128906,
#        167.40037536621094,
#        323.9630432128906)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (35.03148651123047,
#      316.9630432128906,
#      167.40037536621094,
#      323.9630432128906)},
#    {'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': '& Overall 11 years of experience)',
#       'origin': (35.027984619140625, 334.7453308105469),
#       'bbox': (35.027984619140625,
#        324.5145568847656,
#        120.2958755493164,
#        331.5145568847656)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (35.027984619140625,
#      324.5145568847656,
#      120.2958755493164,
#      331.5145568847656)}]},
#  {'number': 32,
#   'type': 0,
#   'bbox': (35.02186584472656,
#    339.6175537109375,
#    180.64645385742188,
#    354.1690673828125),
#   'lines': [{'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Mr. Vaibhav Dusad (Managing this fund since Jan, 2021 ',
#       'origin': (35.02497100830078, 349.84832763671875),
#       'bbox': (35.02497100830078,
#        339.6175537109375,
#        180.64645385742188,
#        346.6175537109375)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (35.02497100830078,
#      339.6175537109375,
#      180.64645385742188,
#      346.6175537109375)},
#    {'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': '& Overall 9 years of experience) ',
#       'origin': (35.02186584472656, 357.39984130859375),
#       'bbox': (35.02186584472656,
#        347.1690673828125,
#        118.73577117919922,
#        354.1690673828125)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (35.02186584472656,
#      347.1690673828125,
#      118.73577117919922,
#      354.1690673828125)}]},
#  {'number': 33,
#   'type': 0,
#   'bbox': (35.03960037231445, 368.57421875, 161.25653076171875, 375.57421875),
#   'lines': [{'spans': [{'size': 7.0,
#       'flags': 20,
#       'font': 'ZurichBT-BoldCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Indicative Investment Horizon: ',
#       'origin': (35.03960037231445, 378.80499267578125),
#       'bbox': (35.03960037231445, 368.57421875, 119.26171875, 375.57421875)},
#      {'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': '5 years & above',
#       'origin': (119.26002502441406, 378.80499267578125),
#       'bbox': (119.26002502441406,
#        368.57421875,
#        161.25653076171875,
#        375.57421875)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (35.03960037231445,
#      368.57421875,
#      161.25653076171875,
#      375.57421875)}]},
#  {'number': 34,
#   'type': 0,
#   'bbox': (216.72430419921875,
#    283.8779296875,
#    529.3109741210938,
#    314.7232971191406),
#   'lines': [{'spans': [{'size': 7.0,
#       'flags': 20,
#       'font': 'ZurichBT-BoldCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Inception/Allotment date: ',
#       'origin': (216.72430419921875, 297.0635070800781),
#       'bbox': (216.72430419921875,
#        286.8327331542969,
#        287.2173767089844,
#        293.8327331542969)},
#      {'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': '23-May-08',
#       'origin': (287.2159729003906, 297.0635070800781),
#       'bbox': (287.2159729003906,
#        286.8327331542969,
#        315.4681701660156,
#        293.8327331542969)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (216.72430419921875,
#      286.8327331542969,
#      315.4681701660156,
#      293.8327331542969)},
#    {'spans': [{'size': 7.0,
#       'flags': 20,
#       'font': 'ZurichBT-BoldCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Exit load for Redemption / Switch',
#       'origin': (394.0447082519531, 294.10870361328125),
#       'bbox': (394.0447082519531,
#        283.8779296875,
#        488.6217346191406,
#        290.8779296875)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (394.0447082519531,
#      283.8779296875,
#      488.6217346191406,
#      290.8779296875)},
#    {'spans': [{'size': 7.0,
#       'flags': 20,
#       'font': 'ZurichBT-BoldCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'out :- Lumpsum & SIP / STP / SWP Option',
#       'origin': (394.0447082519531, 302.4989929199219),
#       'bbox': (394.0447082519531,
#        292.2682189941406,
#        510.4617919921875,
#        299.2682189941406)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (394.0447082519531,
#      292.2682189941406,
#      510.4617919921875,
#      299.2682189941406)},
#    {'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Upto 1 Year from allotment - 1% of applicable NAV, ',
#       'origin': (394.0447082519531, 310.8892822265625),
#       'bbox': (394.0447082519531,
#        300.65850830078125,
#        529.3109741210938,
#        307.65850830078125)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (394.0447082519531,
#      300.65850830078125,
#      529.3109741210938,
#      307.65850830078125)},
#    {'spans': [{'size': 7.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'more than 1 Year - Nil',
#       'origin': (394.044189453125, 317.9540710449219),
#       'bbox': (394.044189453125,
#        307.7232971191406,
#        451.2650451660156,
#        314.7232971191406)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (394.044189453125,
#      307.7232971191406,
#      451.2650451660156,
#      314.7232971191406)}]},
#  {'number': 35,
#   'type': 0,
#   'bbox': (395.8216857910156,
#    353.8865966796875,
#    469.7881774902344,
#    377.63275146484375),
#   'lines': [{'spans': [{'size': 6.965263843536377,
#       'flags': 20,
#       'font': 'ZurichBT-BoldCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Total Expense Ratio @@ :',
#       'origin': (395.8216857910156, 364.06658935546875),
#       'bbox': (395.8216857910156,
#        353.8865966796875,
#        469.7881774902344,
#        360.85186767578125)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (395.8216857910156,
#      353.8865966796875,
#      469.7881774902344,
#      360.85186767578125)},
#    {'spans': [{'size': 6.965263843536377,
#       'flags': 20,
#       'font': 'ZurichBT-BoldCondensed',
#       'color': -13159371,
# ...
#        648.9717407226562,
#        455.55120849609375,
#        654.4717407226562)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (394.7003173828125,
#      648.9717407226562,
#      455.55120849609375,
#      654.4717407226562)},
#    {'spans': [{'size': 5.5,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': '• An open ended equity scheme predominantly investing in large cap stocks.',
#       'origin': (394.70062255859375, 662.9437255859375),
#       'bbox': (394.70062255859375,
#        654.9052734375,
#        555.1304931640625,
#        660.4052734375)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (394.70062255859375,
#      654.9052734375,
#      555.1304931640625,
#      660.4052734375)}]},
#  {'number': 84,
#   'type': 0,
#   'bbox': (496.664794921875,
#    723.70947265625,
#    544.98779296875,
#    728.480224609375),
#   'lines': [{'spans': [{'size': 4.770744323730469,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Benchmark riskometer is at ',
#       'origin': (496.664794921875, 730.68212890625),
#       'bbox': (496.664794921875,
#        723.70947265625,
#        544.98779296875,
#        728.480224609375)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (496.664794921875,
#      723.70947265625,
#      544.98779296875,
#      728.480224609375)}]},
#  {'number': 85,
#   'type': 0,
#   'bbox': (507.3787536621094,
#    729.103271484375,
#    533.1862182617188,
#    733.8740234375),
#   'lines': [{'spans': [{'size': 4.770744323730469,
#       'flags': 20,
#       'font': 'ZurichBT-BoldCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Very High ',
#       'origin': (507.3787536621094, 736.075927734375),
#       'bbox': (507.3787536621094,
#        729.103271484375,
#        525.940673828125,
#        733.8740234375)},
#      {'size': 4.770744323730469,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -13159371,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'risk.',
#       'origin': (525.939453125, 736.075927734375),
#       'bbox': (525.939453125,
#        729.103271484375,
#        533.1862182617188,
#        733.8740234375)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (507.3787536621094,
#      729.103271484375,
#      533.1862182617188,
#      733.8740234375)}]},
#  {'number': 86,
#   'type': 0,
#   'bbox': (354.55828857421875,
#    741.0220336914062,
#    368.5482482910156,
#    746.0220336914062),
#   'lines': [{'spans': [{'size': 5.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -16777216,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': '26.33%',
#       'origin': (354.55828857421875, 748.3297119140625),
#       'bbox': (354.55828857421875,
#        741.0220336914062,
#        368.5482482910156,
#        746.0220336914062)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (354.55828857421875,
#      741.0220336914062,
#      368.5482482910156,
#      746.0220336914062)}]},
#  {'number': 87,
#   'type': 0,
#   'bbox': (307.5950927734375,
#    732.3202514648438,
#    321.5850524902344,
#    737.3202514648438),
#   'lines': [{'spans': [{'size': 5.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -16777216,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': '11.84%',
#       'origin': (307.5950927734375, 739.6279296875),
#       'bbox': (307.5950927734375,
#        732.3202514648438,
#        321.5850524902344,
#        737.3202514648438)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (307.5950927734375,
#      732.3202514648438,
#      321.5850524902344,
#      737.3202514648438)}]},
#  {'number': 88,
#   'type': 0,
#   'bbox': (294.72088623046875,
#    723.617919921875,
#    306.31585693359375,
#    728.617919921875),
#   'lines': [{'spans': [{'size': 5.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -16777216,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': '7.87%',
#       'origin': (294.72088623046875, 730.9255981445312),
#       'bbox': (294.72088623046875,
#        723.617919921875,
#        306.31585693359375,
#        728.617919921875)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (294.72088623046875,
#      723.617919921875,
#      306.31585693359375,
#      728.617919921875)}]},
#  {'number': 89,
#   'type': 0,
#   'bbox': (292.5492858886719,
#    714.9158325195312,
#    304.1442565917969,
#    719.9158325195312),
#   'lines': [{'spans': [{'size': 5.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -16777216,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': '7.20%',
#       'origin': (292.5492858886719, 722.2235107421875),
#       'bbox': (292.5492858886719,
#        714.9158325195312,
#        304.1442565917969,
#        719.9158325195312)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (292.5492858886719,
#      714.9158325195312,
#      304.1442565917969,
#      719.9158325195312)}]},
#  {'number': 90,
#   'type': 0,
#   'bbox': (287.2341003417969,
#    706.2137451171875,
#    298.8290710449219,
#    711.2137451171875),
#   'lines': [{'spans': [{'size': 5.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -16777216,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': '5.56%',
#       'origin': (287.2341003417969, 713.5214233398438),
#       'bbox': (287.2341003417969,
#        706.2137451171875,
#        298.8290710449219,
#        711.2137451171875)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (287.2341003417969,
#      706.2137451171875,
#      298.8290710449219,
#      711.2137451171875)}]},
#  {'number': 91,
#   'type': 0,
#   'bbox': (286.456298828125,
#    697.5119018554688,
#    298.05126953125,
#    702.5119018554688),
#   'lines': [{'spans': [{'size': 5.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -16777216,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': '5.32%',
#       'origin': (286.456298828125, 704.819580078125),
#       'bbox': (286.456298828125,
#        697.5119018554688,
#        298.05126953125,
#        702.5119018554688)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (286.456298828125,
#      697.5119018554688,
#      298.05126953125,
#      702.5119018554688)}]},
#  {'number': 92,
#   'type': 0,
#   'bbox': (286.2940979003906,
#    688.8096313476562,
#    297.8890686035156,
#    693.8096313476562),
#   'lines': [{'spans': [{'size': 5.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -16777216,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': '5.27%',
#       'origin': (286.2940979003906, 696.1173095703125),
#       'bbox': (286.2940979003906,
#        688.8096313476562,
#        297.8890686035156,
#        693.8096313476562)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (286.2940979003906,
#      688.8096313476562,
#      297.8890686035156,
#      693.8096313476562)}]},
#  {'number': 93,
#   'type': 0,
#   'bbox': (283.86309814453125,
#    680.1078491210938,
#    295.45806884765625,
#    685.1078491210938),
#   'lines': [{'spans': [{'size': 5.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -16777216,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': '4.52%',
#       'origin': (283.86309814453125, 687.41552734375),
#       'bbox': (283.86309814453125,
#        680.1078491210938,
#        295.45806884765625,
#        685.1078491210938)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (283.86309814453125,
#      680.1078491210938,
#      295.45806884765625,
#      685.1078491210938)}]},
#  {'number': 94,
#   'type': 0,
#   'bbox': (281.6918029785156,
#    671.4053955078125,
#    293.2867736816406,
#    676.4053955078125),
#   'lines': [{'spans': [{'size': 5.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -16777216,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': '3.85%',
#       'origin': (281.6918029785156, 678.7130737304688),
#       'bbox': (281.6918029785156,
#        671.4053955078125,
#        293.2867736816406,
#        676.4053955078125)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (281.6918029785156,
#      671.4053955078125,
#      293.2867736816406,
#      676.4053955078125)}]},
#  {'number': 95,
#   'type': 0,
#   'bbox': (280.68719482421875,
#    662.70361328125,
#    292.28216552734375,
#    667.70361328125),
#   'lines': [{'spans': [{'size': 5.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -16777216,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': '3.54%',
#       'origin': (280.68719482421875, 670.0112915039062),
#       'bbox': (280.68719482421875,
#        662.70361328125,
#        292.28216552734375,
#        667.70361328125)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (280.68719482421875,
#      662.70361328125,
#      292.28216552734375,
#      667.70361328125)}]},
#  {'number': 96,
#   'type': 0,
#   'bbox': (250.33099365234375,
#    740.7632446289062,
#    261.9410095214844,
#    745.7632446289062),
#   'lines': [{'spans': [{'size': 5.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -16777216,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Banks',
#       'origin': (250.33099365234375, 748.0709228515625),
#       'bbox': (250.33099365234375,
#        740.7632446289062,
#        261.9410095214844,
#        745.7632446289062)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (250.33099365234375,
#      740.7632446289062,
#      261.9410095214844,
#      745.7632446289062)}]},
#  {'number': 97,
#   'type': 0,
#   'bbox': (244.7812957763672,
#    732.0614013671875,
#    261.9813232421875,
#    737.0614013671875),
#   'lines': [{'spans': [{'size': 5.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -16777216,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Software',
#       'origin': (244.7812957763672, 739.3690795898438),
#       'bbox': (244.7812957763672,
#        732.0614013671875,
#        261.9813232421875,
#        737.0614013671875)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (244.7812957763672,
#      732.0614013671875,
#      261.9813232421875,
#      737.0614013671875)}]},
#  {'number': 98,
#   'type': 0,
#   'bbox': (225.0944061279297,
#    723.359130859375,
#    261.939208984375,
#    728.359130859375),
#   'lines': [{'spans': [{'size': 5.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -16777216,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Petroleum Products',
#       'origin': (225.0944061279297, 730.6668090820312),
#       'bbox': (225.0944061279297,
#        723.359130859375,
#        261.939208984375,
#        728.359130859375)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (225.0944061279297,
#      723.359130859375,
#      261.939208984375,
#      728.359130859375)}]},
#  {'number': 99,
#   'type': 0,
#   'bbox': (252.95269775390625,
#    714.6572875976562,
#    261.9626770019531,
#    719.6572875976562),
#   'lines': [{'spans': [{'size': 5.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -16777216,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Auto',
#       'origin': (252.95269775390625, 721.9649658203125),
#       'bbox': (252.95269775390625,
#        714.6572875976562,
#        261.9626770019531,
#        719.6572875976562)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (252.95269775390625,
#      714.6572875976562,
#      261.9626770019531,
#      719.6572875976562)}]},
#  {'number': 100,
#   'type': 0,
#   'bbox': (226.2707977294922,
#    705.9548950195312,
#    261.9370422363281,
#    710.9548950195312),
#   'lines': [{'spans': [{'size': 5.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -16777216,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Telecom - Services',
#       'origin': (226.2707977294922, 713.2625732421875),
#       'bbox': (226.2707977294922,
#        705.9548950195312,
#        261.9370422363281,
#        710.9548950195312)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (226.2707977294922,
#      705.9548950195312,
#      261.9370422363281,
#      710.9548950195312)}]},
#  {'number': 101,
#   'type': 0,
#   'bbox': (223.50900268554688,
#    697.2531127929688,
#    261.9023132324219,
#    702.2531127929688),
#   'lines': [{'spans': [{'size': 5.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -16777216,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Construction Project',
#       'origin': (223.50900268554688, 704.560791015625),
#       'bbox': (223.50900268554688,
#        697.2531127929688,
#        261.9023132324219,
#        702.2531127929688)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (223.50900268554688,
#      697.2531127929688,
#      261.9023132324219,
#      702.2531127929688)}]},
#  {'number': 102,
#   'type': 0,
#   'bbox': (247.26980590820312,
#    688.5508422851562,
#    261.97979736328125,
#    693.5508422851562),
#   'lines': [{'spans': [{'size': 5.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -16777216,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Finance',
#       'origin': (247.26980590820312, 695.8585205078125),
#       'bbox': (247.26980590820312,
#        688.5508422851562,
#        261.97979736328125,
#        693.5508422851562)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (247.26980590820312,
#      688.5508422851562,
#      261.97979736328125,
#      693.5508422851562)}]},
#  {'number': 103,
#   'type': 0,
#   'bbox': (230.61199951171875,
#    679.8489990234375,
#    261.93701171875,
#    684.8489990234375),
#   'lines': [{'spans': [{'size': 5.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -16777216,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Pharmaceuticals',
#       'origin': (230.61199951171875, 687.1566772460938),
#       'bbox': (230.61199951171875,
#        679.8489990234375,
#        261.93701171875,
#        684.8489990234375)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (230.61199951171875,
#      679.8489990234375,
#      261.93701171875,
#      684.8489990234375)}]},
#  {'number': 104,
#   'type': 0,
#   'bbox': (216.15870666503906,
#    671.1466064453125,
#    261.9387512207031,
#    676.1466064453125),
#   'lines': [{'spans': [{'size': 5.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -16777216,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Consumer Non Durables',
#       'origin': (216.15870666503906, 678.4542846679688),
#       'bbox': (216.15870666503906,
#        671.1466064453125,
#        261.9387512207031,
#        676.1466064453125)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (216.15870666503906,
#      671.1466064453125,
#      261.9387512207031,
#      676.1466064453125)}]},
#  {'number': 105,
#   'type': 0,
#   'bbox': (243.55979919433594,
#    662.44482421875,
#    261.97979736328125,
#    667.44482421875),
#   'lines': [{'spans': [{'size': 5.0,
#       'flags': 4,
#       'font': 'ZurichBT-RomanCondensed',
#       'color': -16777216,
#       'ascender': 0.7599999904632568,
#       'descender': 0.23999999463558197,
#       'text': 'Insurance',
#       'origin': (243.55979919433594, 669.7525024414062),
#       'bbox': (243.55979919433594,
#        662.44482421875,
#        261.97979736328125,
#        667.44482421875)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (243.55979919433594,
#      662.44482421875,
#      261.97979736328125,
#      667.44482421875)}]}]

# %%
text_data = extract_span_data(finalData,'text')

# %%
text_data['Page: 1']
# Out:
# ['ICICI Prudential Bluechip Fund',
#  'Large Cap Fund',
#  'Category',
#  '(An open ended equity scheme predominantly investing in large cap stocks.)',
#  'Returns of ICICI Prudential Bluechip Fund - Growth Option as on October 31, 2021 ',
#  'Style Box',
#  '1 Year',
#  '3 Years',
#  '5 Years',
#  'Since inception',
#  'Particulars',
#  'Current ',
#  'Value of',
#  ' Investment ',
#  'of Rs. 10000',
#  'Current ',
#  'Value of',
#  ' Investment ',
#  'of Rs. 10000',
#  'Current ',
#  'Value of',
#  ' Investment ',
#  'of Rs. 10000',
#  'Current ',
#  'Value of',
#  ' Investment ',
#  'of Rs. 10000',
#  'CAGR ',
#  'CAGR ',
#  'CAGR ',
#  'CAGR ',
#  '(%)',
#  '(%)',
#  '(%)',
#  '(%)',
#  'Style',
#  '57.59 ',
#  '15739.86 ',
#  '18.87 ',
#  '16789.71 ',
#  '15.34 ',
#  '20430.61 ',
#  '15.06 ',
#  '65950.00',
#  '54.01 ',
#  '15382.80 ',
#  '20.41 ',
#  '17447.37 ',
#  '16.37 ',
#  '21354.84 ',
#  '11.77 ',
#  '44654.60',
#  '53.72 ',
#  '15354.21 ',
#  '20.82 ',
#  '17625.49 ',
#  '16.81 ',
#  '21761.33 ',
#  '11.28 ',
#  '42056.47',
#  'Scheme',
#  'Value  Blend  Growth',
#  'Size',
#  'Nifty 100 TRI (Benchmark)',
#  'Large',
#  'Nifty 50 TRI (Additional Benchmark)',
#  '10.00',
#  '41.90',
#  '39.28',
#  '32.28',
#  'NAV (Rs.) Per Unit (as on October 29,2021 : 65.95)',
#  'Mid',
#  'Notes:',
#  '1.\xa0Different plans shall have different expense structure. The performance details provided herein are of ICICI Prudential Bluechip Fund.',
#  '2.\xa0The scheme is currently managed by Anish Tawakley, Rajat Chandak and Vaibhav Dusad. Mr. Anish Tawakley has been managing this fund since Sep 2018. Total Schemes managed by the Fund Manager is 5 (5 ',
#  'Small',
#  'are jointly managed). ',
#  ' ',
#  'Mr. Rajat Chandak has been managing this fund since Jul 2017. Total Schemes managed by the Fund Manager is 5 (4 are jointly managed).',
#  ' ',
#  'Mr. Vaibhav Dusad has been managing this fund since Jan 2021. Total Schemes managed by the Fund Manager is 3 (2 are jointly managed).  Refer annexure from page no. 134 for performance of other schemes ',
#  'currently managed by Anish Tawakley, Rajat Chandak and Vaibhav Dusad.',
#  '3.  Date of inception:23-May-08.',
#  '4.  Past performance may or may not be sustained in future and the same may not necessarily provide the basis for comparison with other investment.',
#  '5.  Load is not considered for computation of returns.',
#  '6.  In case, the start/end date of the concerned period is a nonbusiness date (NBD), the NAV of the previous date is considered for computation of returns. The NAV per unit shown in the table is as on the start date of ',
#  'Diversified',
#  'the said period',
#  '7.  The performance of the scheme is benchmarked to the Total Return variant of the Index. The benchmark of the scheme has been revised from Nifty 50 TRI to Nifty 100 TRI w.e.f. May 28, 2018.',
#  'Fund Details',
#  'Inception/Allotment date: ',
#  '23-May-08',
#  'Exit load for Redemption / Switch',
#  'out :- Lumpsum & SIP / STP / SWP Option',
#  'Upto 1 Year from allotment - 1% of applicable NAV, ',
#  'more than 1 Year - Nil',
#  'Fund Managers** :',
#  'Anish Tawakley (Managing this fund since Sep, 2018 ',
#  '& Overall 26 years of experience)',
#  'Monthly AAUM as on 31-Oct-21 :  ',
#  'Rs. 31,369.46 crores',
#  'Rajat Chandak (Managing this fund since Jul, 2017 ',
#  '& Overall 11 years of experience)',
#  'Closing AUM as on 31-Oct-21 : ',
#  'Rs. 31,081.90 crores',
#  '`',
#  'Application Amount for fresh Subscription :',
#  'Rs.100 (plus in multiples of Re.1)',
#  'Mr. Vaibhav Dusad (Managing this fund since Jan, 2021 ',
#  '& Overall 9 years of experience) ',
#  'Total Expense Ratio @@ :',
#  'Other : ',
#  '1.73% p. a.',
#  'Direct : ',
#  '1.09% p. a.',
#  'Min.Addl.Investment :',
#  'Rs.100 (plus in multiples of Re.1)',
#  'Indicative Investment Horizon: ',
#  '5 years & above',
#  'NAV (As on 29-Oct-21):',
#  ' ',
#  'Growth Option : 65.95 ',
#  'IDCW Option : 27.49 ',
#  'Direct Plan Growth Option : 70.85 ',
#  'Direct Plan IDCW Option : 45.43',
#  '`',
#  '`',
#  '`',
#  '`',
#  '`',
#  'Quantitative Indicators ',
#  'Portfolio as on October 31, 2021',
#  'Average ',
#  'Dividend Yield : ',
#  'Company/Issuer ',
#  '           ',
#  '% to  % to NAV',
#  ' ',
#  ' ',
#  ' ',
#  'NAV Derivatives',
#  'Company/Issuer ',
#  '             ',
#  '% to  % to NAV',
#  ' ',
#  ' ',
#  ' ',
#  'NAV Derivatives',
#  'Average P/E : ',
#  'Average P/B : ',
#  '35.21',
#  '5.82',
#  '0.95',
#  ' ',
#  'Equity Shares ',
#  ' ',
#  '95.35% -3.46%',
#  ' ',
#  'Auto ',
#  ' ',
#  '5.75% ',
#  '• Maruti Suzuki India Ltd. ',
#  ' ',
#  '3.45% ',
#  ' ',
#  'TVS Motor Company Ltd. ',
#  ' ',
#  '2.30% ',
#  ' ',
#  'Banks ',
#  ' ',
#  '25.85% ',
#  '• ICICI Bank Ltd. ',
#  ' ',
#  '10.27% ',
#  '• HDFC Bank Ltd. ',
#  ' ',
#  '8.18% ',
#  '• Axis Bank Ltd. ',
#  ' ',
#  '5.38% ',
#  ' ',
#  'Kotak Mahindra Bank Ltd.  ',
#  '1.20% ',
#  ' ',
#  'State Bank Of India ',
#  ' ',
#  '0.82% ',
#  ' ',
#  'Cement & Cement Products ',
#  '2.17% ',
#  ' ',
#  'Grasim Industries Ltd. ',
#  ' ',
#  '1.27% ',
#  ' ',
#  'Ultratech Cement Ltd. ',
#  ' ',
#  '0.90% ',
#  ' ',
#  'Construction Project ',
#  ' ',
#  '5.32% ',
#  '• Larsen & Toubro Ltd. ',
#  ' ',
#  '5.32% ',
#  ' ',
#  'Consumer Non Durables  ',
#  '2.98% ',
#  ' ',
#  'ITC Ltd. ',
#  ' ',
#  '1.64% ',
#  ' ',
#  'United Breweries Ltd. ',
#  ' ',
#  '1.34% ',
#  ' ',
#  'Ferrous Metals ',
#  ' ',
#  '0.74% ',
#  ' ',
#  'Tata Steel Ltd. ',
#  ' ',
#  '0.74% ',
#  ' ',
#  'Finance ',
#  ' ',
#  '4.62% ',
#  '• HDFC Ltd. ',
#  ' ',
#  '4.62% ',
#  ' ',
#  'Insurance ',
#  ' ',
#  '2.75% ',
#  ' ',
#  'SBI Life Insurance Company Ltd. ',
#  '2.75% ',
#  ' ',
#  'Non - Ferrous Metals ',
#  ' ',
#  '1.65% ',
#  ' ',
#  'Hindalco Industries Ltd. ',
#  ' ',
#  '1.65% ',
#  ' ',
#  'Oil ',
#  ' ',
#  '1.40% -0.02%',
#  ' ',
#  'Oil & Natural Gas Corporation Ltd. ',
#  '1.40% -0.02%',
#  ' ',
#  'Petroleum Products ',
#  ' ',
#  '7.87% ',
#  '• Reliance Industries Ltd. ',
#  ' ',
#  '6.46% ',
#  ' ',
#  'Bharat Petroleum Corporation Ltd. ',
#  '1.41% ',
#  ' ',
#  'Pharmaceuticals ',
#  ' ',
#  '3.53% ',
#  ' ',
#  'Sun Pharmaceutical Industries Ltd. ',
#  '1.64% ',
#  ' ',
#  'Cipla Ltd. ',
#  ' ',
#  '1.19% ',
#  ' ',
#  'Lupin Ltd. ',
#  ' ',
#  '0.70% ',
#  ' ',
#  'Power ',
#  ' ',
#  '1.44% ',
#  ' ',
#  'NTPC Ltd. ',
#  ' ',
#  '1.44% ',
#  ' ',
#  'Retailing ',
#  ' ',
#  '2.32% ',
#  ' ',
#  'Avenue Supermarts Ltd. ',
#  ' ',
#  '2.32% ',
#  '(D-Mart)',
#  ' ',
#  'Software ',
#  ' ',
#  '11.50% ',
#  '• Infosys Ltd. ',
#  ' ',
#  '6.51% ',
#  '• HCL Technologies Ltd. ',
#  ' ',
#  '2.91% ',
#  ' ',
#  'Tech Mahindra Ltd. ',
#  ' ',
#  '2.08% ',
#  ' ',
#  'Telecom - Services ',
#  ' ',
#  '5.56% ',
#  '• Bharti Airtel Ltd. ',
#  ' ',
#  '5.56% ',
#  ' ',
#  'Foreign Equity ',
#  ' ',
#  '0.53% ',
#  ' ',
#  'Index Futures/Options ',
#  ' ',
#  ' -3.43%',
#  ' ',
#  'Nifty 50 Index - Futures ',
#  ' ',
#  ' -3.43%',
#  ' ',
#  'Treasury Bills ',
#  ' ',
#  '0.55% ',
#  ' ',
#  '182 Days Treasury Bill 2021 SOV ',
#  '0.42% ',
#  ' ',
#  '91 Days Treasury Bill 2022 SOV ',
#  '0.13% ',
#  ' ',
#  'Equity less than 1% of corpus ',
#  '9.90% ',
#  ' ',
#  'Short Term Debt and net current assets ',
#  '7.56% ',
#  ' ',
#  'Total Net Assets ',
#  ' ',
#  '100.00% ',
#  'Annual Portfolio Turnover Ratio : ',
#  'Equity - 0.19 times',
#  'Std Dev ',
#  '(Annualised) : ',
#  'Sharpe Ratio : ',
#  'Portfolio Beta : ',
#  '0.79',
#  '0.95',
#  '20.49%',
#  'The figures are not netted for derivative transactions.',
#  'Risk-free rate based on the last Overnight MIBOR cut-off of 3.42%',
#  '**In addition to the fund manager managing this fund, overseas investment is managed by Ms. ',
#  'Priyanka Khandelwal.',
#  '@@ Total Expense Ratio is as on the last business day of the month.',
#  'The Global Industry Classification Standard (“GICS”) was developed by and is the exclusive ',
#  'property and a service mark of MSCI Inc. (“MSCI”) and Standard & Poor’s Financial Services LLC ',
#  '(“S&P”) and is licensed for use by ICICI Prudential Asset Management Company Ltd. Neither ',
#  'MSCI, S&P nor any other party involved in making or compiling the GICS or any GICS ',
#  'classifications makes any express or implied warranties or representations with respect to such ',
#  'standard or classification (or the results to be obtained by the use thereof), and all such parties ',
#  'hereby expressly disclaim all warranties of originality, accuracy, completeness, ',
#  'merchantability and fitness for a particular purpose with respect to any of such standard or ',
#  'classification. Without limiting any of the foregoing, in no event shall MSCI, S&P, any of their ',
#  'affiliates or any third party involved in making or compiling the GICS or any GICS classifications ',
#  'have any liability for any direct, indirect, special, punitive, consequential or any other damages ',
#  '(including lost profits) even if notified of the possibility of such damages.',
#  'Refer page no 124 to 133 for details on option, entry load, SWP, STP/Flex STP/Value STP & ',
#  'minimum redemption amount pertaining to the scheme.',
#  'For IDCW History : Refer page no. from 154 to 161, For SIP Returns : Refer page no. from 149 to ',
#  '152, For Investment Objective : Refer page no. from 162 to 166',
#  '• Top Ten Holdings',
#  'Securities and the corresponding derivative exposure with less than 1% ',
#  'to NAV, have been clubbed together with a consolidated limit of 10%.',
#  'Derivatives are considered at exposure value.',
#  'Riskometer',
#  'This product labelling is applicable only to the scheme ',
#  'This Product is suitable for investors who are seeking*:',
#  '• Long Term Wealth Creation',
#  '• An open ended equity scheme predominantly investing in large cap stocks.',
#  'Top 10 Sectors',
#  'Benchmark ',
#  'Insurance',
#  '3.54%',
#  'Scheme',
#  '(Nifty 100 TRI)',
#  'Consumer Non Durables',
#  '3.85%',
#  'Pharmaceuticals',
#  '4.52%',
#  'Finance',
#  '5.27%',
#  'Construction Project',
#  '5.32%',
#  'Telecom - Services',
#  '5.56%',
#  'Auto',
#  '7.20%',
#  'Investors understand that their principal ',
#  'Petroleum Products',
#  '7.87%',
#  'Benchmark riskometer is at ',
#  'will be at ',
#  'Very High',
#  ' risk',
#  'Very High ',
#  'risk.',
#  'Software',
#  '11.84%',
#  'Banks',
#  '26.33%',
#  '*Investors should consult their financial advisers if in doubt about whether the',
#  'product is suitable for them.',
#  '16']
