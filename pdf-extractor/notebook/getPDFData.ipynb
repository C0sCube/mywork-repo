# %%
# !pip install PyPDF2

# %%
import requests
from bs4 import BeautifulSoup
import PyPDF2, json
import requests, string

# %%
file_path = r"/content/sample.pdf"
json_path = r"/content/sample.json"

# %%
def get_text_from_pdf(file_path):
    text = ""
    with open(file_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        num_pages = len(reader.pages)
        print(num_pages);
        for page_num in range(num_pages):
            page = reader.pages[page_num]
            text += page.extract_text()
    #print(text)
    return text

def get_header_content(file_path):
  pdf_document = fitz.open(file_path)
  text_font_size = []

  for page_num in range(len(pdf_document)):
      page = pdf_document[page_num]
      blocks = page.get_text("dict")["blocks"]
      for block in blocks:
          if "lines" in block:
              for line in block["lines"]:
                  for span in line["spans"]:
                      text_font_size.append((span["text"], span["size"]))


  #create key value pair based on font size
  header =[]
  content = []
  threshold = 12

  for line_set in text_font_size:
    line_size = line_set[1]
    if line_size>threshold:
      header.append(line_set[0])
    else:
      content.append(line_set[0])




  return " ".join(header), " ".join(content)



#text = get_text_from_pdf(file_path)
header, content = get_header_content(file_path)

print("header:",header)
print("content:", content)
# Out:
# header: Sample PDF This is a simple PDF ﬁle. Fun fun fun.
# ...

# %%
def text_clean(text):

# %%
# text extracted in raw form , convert and clean the data

# %%
def save_text_to_json(text, json_path):
    # Convert to dictionary
    data = {"content": text}

    # JSON file
    with open(json_path, 'w') as json_file:
        json.dump(data, json_file, indent=4)

# %%
text = get_text_from_pdf(file_path)
for page in text:
  print(page)
# Json file saved
save_text_to_json(text, json_path)

print(f"Text extracted and saved to {json_path}")
# Out:
# 1
# ...
